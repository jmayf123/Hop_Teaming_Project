# %%
import pandas as pd
import sqlite3
import numpy as np

# %% [markdown]
# ### First, build a profile of providers referring patients to the major hospitals in Nashville. Are certain specialties more likely to refer to a particular hospital over the others?

# %%
#Check the classification and the corresponding counts

# %%
#Find all the provider hospital(Entity Type =2) refererring to Nashville area 
#hospitals(hospitals can be identified with classification code = General Acute Care Hospital)

#Create a CTE
sql = """
WITH CTE_referers AS (
        SELECT distinct npi, organization_name  FROM npi 
        LEFT JOIN taxonomy  USING(taxonomy_code)
        WHERE location_address_state_name = 'TN' 
                AND entity_type_code = 2 
                AND location_address_city_name LIKE 'Nashville%' 
                AND classification = 'General Acute Care Hospital'
)
SELECT 
        h.from_npi
        ,h.to_npi
        ,h.patient_count
        ,cte.organization_name
        ,n.last_name  
        ,n.first_name   
        ,n.location_address_city_name 
        ,n.location_address_state_name 
        ,n.location_address_postal_code 
        ,n.entity_type_code 
        ,t.taxonomy_code 
        ,t.grouping  
        ,t.classification  
        ,t.specialization 
        ,t.display_name 
FROM hop h 
INNER JOIN npi n on h.from_npi = n.npi
inner join CTE_referers cte on cte.npi = h.to_npi
 LEFT JOIN taxonomy t USING(taxonomy_code)
WHERE h.transaction_count >= 50
        AND h.average_day_wait < 50
        And entity_type_code < 2
"""

# %%
with sqlite3.connect('../data/hop_db.sqlite') as db: 
    df_referrers = pd.read_sql(sql, db)

# %%
df_referrers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5248 entries, 0 to 5247
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   from_npi                      5248 non-null   int64
#  1   to_npi                        5248 non-null   int64
#  2   patient_count                 5248 non-null   int64
#  3   organization_name             5248 non-null   object
#  4   last_name                     5248 non-null   object
#  5   first_name                    5248 non-null   object
#  6   location_address_city_name    5248 non-null   object
#  7   location_address_state_name   5248 non-null   object
#  8   location_address_postal_code  5248 non-null   object
#  9   entity_type_code              5248 non-null   float64
#  10  taxonomy_code                 5248 non-null   object
#  11  grouping                      5248 non-null   object
#  12  classification                5248 non-null   object
#  13  specialization                2689 non-null   object
#  14  display_name                  5248 non-null   object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 615.1+ KB

# %%
df_referrers['entity_type_code'].value_counts()
# Out:
# 1.0    5248
# Name: entity_type_code, dtype: int64

# %%
#find top referred hospitals in nashville by patient count
sql = """
WITH cte_referrers AS (
        SELECT distinct npi, organization_name  FROM npi 
        LEFT JOIN taxonomy  USING(taxonomy_code)
        WHERE location_address_state_name = 'TN' 
                AND entity_type_code = 2 
                AND location_address_city_name LIKE 'Nashville%' 
                AND classification = 'General Acute Care Hospital'
)
SELECT n.organization_name as hospital, SUM(patient_count) tot_patients
FROM hop h
        INNER JOIN npi n ON  h.to_npi = n.npi
        INNER JOIN cte_referrers cte ON h.to_npi = cte.npi
GROUP BY n.organization_name
ORDER BY 2 desc
"""

with sqlite3.connect('../data/hop_db.sqlite') as db: 
    df_nash_top_hosp = pd.read_sql(sql, db)

# %%
df_nash_top_hosp
# Out:
#                                  hospital  tot_patients
# 0    VANDERBILT UNIVERSITY MEDICAL CENTER       1352091
# 1              SAINT THOMAS WEST HOSPITAL        827346
# 2  HCA HEALTH SERVICES OF TENNESSEE, INC.        678400
# 3       HTI MEMORIAL HOSPITAL CORPORATION        225244
# 4              NASHVILLE GENERAL HOSPITAL         16642
# 5                       SETON CORPORATION          3294

# %%
#Find referrer by speciality
sql = """
WITH cte_referrers AS (
        SELECT distinct npi, organization_name  FROM npi 
        LEFT JOIN taxonomy  USING(taxonomy_code)
        WHERE location_address_state_name = 'TN' 
                AND entity_type_code = 2 
                AND location_address_city_name LIKE 'Nashville%' 
                AND classification = 'General Acute Care Hospital'
)
SELECT 
        t.display_name AS specialty_referrer,
        cte.organization_name AS organization_name_referred,
        COUNT(cte.organization_name) as count_referred
FROM hop h 
INNER JOIN npi n  ON h.from_npi = n.npi
LEFT JOIN taxonomy t USING(taxonomy_code)
INNER JOIN cte_referrers cte ON h.to_npi = cte.npi
WHERE transaction_count >= 50
AND average_day_wait < 50
    AND n.entity_type_code < 2   
GROUP BY organization_name_referred, specialty_referrer
ORDER BY 3 DESC
"""

with sqlite3.connect('../data/hop_db.sqlite') as db: 
    df_referrer_speciality = pd.read_sql(sql, db)

# %%
df_referrer_speciality
# Out:
#                                     specialty_referrer  \
# 0                          Internal Medicine Physician
# 1                            Family Medicine Physician
# 2                          Internal Medicine Physician
# 3                       Diagnostic Radiology Physician
# 4                            Family Nurse Practitioner
# ..                                                 ...
# 395            Pediatric Orthopaedic Surgery Physician
# 396                      Pediatric Pathology Physician
# 397                      Pediatric Radiology Physician
# 398        Sports Medicine (Family Medicine) Physician
# 399  Student in an Organized Health Care Education/...
#
#                  organization_name_referred  count_referred
# 0      VANDERBILT UNIVERSITY MEDICAL CENTER             319
# 1      VANDERBILT UNIVERSITY MEDICAL CENTER             203
# 2                SAINT THOMAS WEST HOSPITAL             191
# 3    HCA HEALTH SERVICES OF TENNESSEE, INC.             163
# 4      VANDERBILT UNIVERSITY MEDICAL CENTER             146
# ..                                      ...             ...
# 395    VANDERBILT UNIVERSITY MEDICAL CENTER               1
# 396    VANDERBILT UNIVERSITY MEDICAL CENTER               1
# 397    VANDERBILT UNIVERSITY MEDICAL CENTER               1
# 398    VANDERBILT UNIVERSITY MEDICAL CENTER               1
# 399    VANDERBILT UNIVERSITY MEDICAL CENTER               1
#
# [400 rows x 3 columns]

# %%
df_referrers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5248 entries, 0 to 5247
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   from_npi                      5248 non-null   int64
#  1   to_npi                        5248 non-null   int64
#  2   patient_count                 5248 non-null   int64
#  3   organization_name             5248 non-null   object
#  4   last_name                     5248 non-null   object
#  5   first_name                    5248 non-null   object
#  6   location_address_city_name    5248 non-null   object
#  7   location_address_state_name   5248 non-null   object
#  8   location_address_postal_code  5248 non-null   object
#  9   entity_type_code              5248 non-null   float64
#  10  taxonomy_code                 5248 non-null   object
#  11  grouping                      5248 non-null   object
#  12  classification                5248 non-null   object
#  13  specialization                2689 non-null   object
#  14  display_name                  5248 non-null   object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 615.1+ KB

# %%
df.head(100)

# %%
#AK
#Find the Referrer and referred
sql = """
WITH cte_nash_hosp AS (
        SELECT distinct npi, organization_name, display_name  FROM npi 
        LEFT JOIN taxonomy  USING(taxonomy_code)
        WHERE location_address_state_name = 'TN' 
                AND entity_type_code = 2 
                AND location_address_city_name LIKE 'Nashville%' 
                AND classification = 'General Acute Care Hospital'
)
SELECT 
        h.from_npi 
        ,h.patient_count
        ,h.transaction_count
        ,h.average_day_wait
        ,h.std_day_wait
        ,t.display_name as from_speciality
        ,cte.npi as to_npi
        ,cte.organization_name as to_organization_name
        ,cte.display_name as to_speciality
FROM hop h 
        INNER JOIN npi fn  ON h.from_npi = fn.npi
LEFT JOIN taxonomy t USING(taxonomy_code)
        INNER JOIN cte_nash_hosp cte ON h.to_npi = cte.npi
WHERE transaction_count >= 50
        AND average_day_wait < 50
        AND fn.entity_type_code < 2  
"""

with sqlite3.connect('../data/hop_db.sqlite') as db: 
    df_ref = pd.read_sql(sql, db)

# %%
df_ref
# Out:
#         from_npi  patient_count  transaction_count  average_day_wait  \
# 0     1679521090             36                 62            10.306
# 1     1043232879             47                 55            18.727
# 2     1174565543             69                143             3.273
# 3     1942254883             52                 65            13.154
# 4     1194751354             37                 64            12.641
# ...          ...            ...                ...               ...
# 5243  1952542698             33                 58            26.172
# 5244  1194812297             70                163             1.816
# 5245  1225372733             41                 57             6.684
# 5246  1962596734             53                 94             0.638
# 5247  1972616407            168                422             2.173
#
#       std_day_wait                               from_speciality      to_npi  \
# 0           39.479               Hematology & Oncology Physician  1992861314
# 1           44.898                Diagnostic Radiology Physician  1992861314
# 2           26.756               Hematology & Oncology Physician  1992861314
# 3           32.501                Diagnostic Radiology Physician  1992861314
# 4           38.231                    Medical Oncology Physician  1992861314
# ...            ...                                           ...         ...
# 5243        24.077                                    Podiatrist  1558408633
# 5244        16.108  Psychiatric/Mental Health Nurse Practitioner  1558408633
# 5245        19.407        Certified Registered Nurse Anesthetist  1558408633
# 5246         6.189                          Psychiatry Physician  1558408633
# 5247        10.972                          Psychiatry Physician  1558408633
#
#                       to_organization_name                to_speciality
# 0                        SETON CORPORATION  General Acute Care Hospital
# 1                        SETON CORPORATION  General Acute Care Hospital
# 2                        SETON CORPORATION  General Acute Care Hospital
# 3                        SETON CORPORATION  General Acute Care Hospital
# 4                        SETON CORPORATION  General Acute Care Hospital
# ...                                    ...                          ...
# 5243  VANDERBILT UNIVERSITY MEDICAL CENTER  General Acute Care Hospital
# 5244  VANDERBILT UNIVERSITY MEDICAL CENTER  General Acute Care Hospital
# 5245  VANDERBILT UNIVERSITY MEDICAL CENTER  General Acute Care Hospital
# 5246  VANDERBILT UNIVERSITY MEDICAL CENTER  General Acute Care Hospital
# 5247  VANDERBILT UNIVERSITY MEDICAL CENTER  General Acute Care Hospital
#
# [5248 rows x 9 columns]

# %%
df_ref.groupby(['to_organization_name', 'from_speciality'])['from_npi'].count().reset_index()
# Out:
#                        to_organization_name  \
# 0    HCA HEALTH SERVICES OF TENNESSEE, INC.
# 1    HCA HEALTH SERVICES OF TENNESSEE, INC.
# 2    HCA HEALTH SERVICES OF TENNESSEE, INC.
# 3    HCA HEALTH SERVICES OF TENNESSEE, INC.
# 4    HCA HEALTH SERVICES OF TENNESSEE, INC.
# ..                                      ...
# 395    VANDERBILT UNIVERSITY MEDICAL CENTER
# 396    VANDERBILT UNIVERSITY MEDICAL CENTER
# 397    VANDERBILT UNIVERSITY MEDICAL CENTER
# 398    VANDERBILT UNIVERSITY MEDICAL CENTER
# 399    VANDERBILT UNIVERSITY MEDICAL CENTER
#
#                                        from_speciality  from_npi
# 0                        Acute Care Nurse Practitioner        18
# 1    Adolescent Medicine (Internal Medicine) Physician         1
# 2                      Adult Health Nurse Practitioner        11
# 3                             Adult Medicine Physician         1
# 4    Adult Reconstructive Orthopaedic Surgery Physi...         2
# ..                                                 ...       ...
# 395                                  Urology Physician        26
# 396      Vascular & Interventional Radiology Physician         5
# 397                       Vascular Neurology Physician         2
# 398                         Vascular Surgery Physician        11
# 399                  Women's Health Nurse Practitioner        10
#
# [400 rows x 3 columns]

# %%
#AK find the top referred nsahville hospitals by from npi count
df1= df_ref.groupby(['to_organization_name', 'from_speciality'])['patient_count'].sum().reset_index().sort_values('patient_count', ascending = False)
df1 = df1.sort_values(by = ['from_speciality', 'patient_count'], ascending = [False, False])
#df1['from_speciality_Rank'] = df1['from_speciality'].rank(method='max')
#df1 = df1[df1['to_organization_name'] =='VANDERBILT UNIVERSITY MEDICAL CENTER']
#pd.pivot(data=df1,index=['from_speciality','to_organization_name'])

pd.pivot(df2, index=['to_organization_name'], columns = 'from_speciality',values = 'patient_count') #Reshape from long to wide
# Out:
# from_speciality                         Acute Care Clinical Nurse Specialist  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                   NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                      166.0
# NASHVILLE GENERAL HOSPITAL                                               NaN
# SAINT THOMAS WEST HOSPITAL                                               NaN
# SETON CORPORATION                                                        NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                   128.0
#
# from_speciality                         Acute Care Nurse Practitioner  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                         2313.0
# HTI MEMORIAL HOSPITAL CORPORATION                               618.0
# NASHVILLE GENERAL HOSPITAL                                       53.0
# SAINT THOMAS WEST HOSPITAL                                     4021.0
# SETON CORPORATION                                                 NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                          13136.0
#
# from_speciality                         Addiction Medicine (Internal Medicine) Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                               NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                                    NaN
# NASHVILLE GENERAL HOSPITAL                                                           NaN
# SAINT THOMAS WEST HOSPITAL                                                          84.0
# SETON CORPORATION                                                                    NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                                 NaN
#
# from_speciality                         Addiction Medicine (Psychiatry & Neurology) Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                                NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                                     NaN
# NASHVILLE GENERAL HOSPITAL                                                            NaN
# SAINT THOMAS WEST HOSPITAL                                                            NaN
# SETON CORPORATION                                                                     NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                                128.0
#
# from_speciality                         Addiction Psychiatry Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                             NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                  NaN
# NASHVILLE GENERAL HOSPITAL                                         NaN
# SAINT THOMAS WEST HOSPITAL                                         NaN
# SETON CORPORATION                                                  NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                              89.0
#
# from_speciality                         Adolescent Medicine (Internal Medicine) Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                               30.0
# HTI MEMORIAL HOSPITAL CORPORATION                                                     NaN
# NASHVILLE GENERAL HOSPITAL                                                            NaN
# SAINT THOMAS WEST HOSPITAL                                                           48.0
# SETON CORPORATION                                                                     NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                                 68.0
#
# from_speciality                         Adult Congenital Heart Disease Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                       NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                            NaN
# NASHVILLE GENERAL HOSPITAL                                                   NaN
# SAINT THOMAS WEST HOSPITAL                                                   NaN
# SETON CORPORATION                                                            NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                        70.0
#
# from_speciality                         Adult Health Nurse Practitioner  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                            867.0
# HTI MEMORIAL HOSPITAL CORPORATION                                 202.0
# NASHVILLE GENERAL HOSPITAL                                          NaN
# SAINT THOMAS WEST HOSPITAL                                        677.0
# SETON CORPORATION                                                   NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                             6305.0
#
# from_speciality                         Adult Medicine Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                     396.0
# HTI MEMORIAL HOSPITAL CORPORATION                            NaN
# NASHVILLE GENERAL HOSPITAL                                   NaN
# SAINT THOMAS WEST HOSPITAL                                   NaN
# SETON CORPORATION                                            NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                        81.0
#
# from_speciality                         Adult Psychiatric/Mental Health Clinical Nurse Specialist  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                                NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                                     NaN
# NASHVILLE GENERAL HOSPITAL                                                            NaN
# SAINT THOMAS WEST HOSPITAL                                                            NaN
# SETON CORPORATION                                                                     NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                                 47.0
#
# from_speciality                         ...  Therapeutic Radiology Physician  \
# to_organization_name                    ...
# HCA HEALTH SERVICES OF TENNESSEE, INC.  ...                              NaN
# HTI MEMORIAL HOSPITAL CORPORATION       ...                              NaN
# NASHVILLE GENERAL HOSPITAL              ...                              NaN
# SAINT THOMAS WEST HOSPITAL              ...                            218.0
# SETON CORPORATION                       ...                              NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER    ...                              NaN
#
# from_speciality                         Thoracic Surgery (Cardiothoracic Vascular Surgery) Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                             1157.0
# HTI MEMORIAL HOSPITAL CORPORATION                                                   241.0
# NASHVILLE GENERAL HOSPITAL                                                            NaN
# SAINT THOMAS WEST HOSPITAL                                                          865.0
# SETON CORPORATION                                                                     NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                               1530.0
#
# from_speciality                         Transplant Surgery Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                          61.0
# HTI MEMORIAL HOSPITAL CORPORATION                                NaN
# NASHVILLE GENERAL HOSPITAL                                       NaN
# SAINT THOMAS WEST HOSPITAL                                     142.0
# SETON CORPORATION                                                NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                           880.0
#
# from_speciality                         Trauma Surgery Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                       NaN
# HTI MEMORIAL HOSPITAL CORPORATION                          760.0
# NASHVILLE GENERAL HOSPITAL                                   NaN
# SAINT THOMAS WEST HOSPITAL                                   NaN
# SETON CORPORATION                                            NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                      2254.0
#
# from_speciality                         Urology Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.             1610.0
# HTI MEMORIAL HOSPITAL CORPORATION                   614.0
# NASHVILLE GENERAL HOSPITAL                           31.0
# SAINT THOMAS WEST HOSPITAL                         2098.0
# SETON CORPORATION                                     NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER               6519.0
#
# from_speciality                         Vascular & Interventional Radiology Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                         2271.0
# HTI MEMORIAL HOSPITAL CORPORATION                                              1739.0
# NASHVILLE GENERAL HOSPITAL                                                        NaN
# SAINT THOMAS WEST HOSPITAL                                                      172.0
# SETON CORPORATION                                                                 NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                           1294.0
#
# from_speciality                         Vascular Neurology Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                           NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                NaN
# NASHVILLE GENERAL HOSPITAL                                       NaN
# SAINT THOMAS WEST HOSPITAL                                     389.0
# SETON CORPORATION                                                NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                           411.0
#
# from_speciality                         Vascular Surgery Physician  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                      1181.0
# HTI MEMORIAL HOSPITAL CORPORATION                            200.0
# NASHVILLE GENERAL HOSPITAL                                    70.0
# SAINT THOMAS WEST HOSPITAL                                  1728.0
# SETON CORPORATION                                              NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                        2754.0
#
# from_speciality                         Women's Health Clinical Nurse Specialist  \
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                                       NaN
# HTI MEMORIAL HOSPITAL CORPORATION                                            NaN
# NASHVILLE GENERAL HOSPITAL                                                   NaN
# SAINT THOMAS WEST HOSPITAL                                                 135.0
# SETON CORPORATION                                                            NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                                         NaN
#
# from_speciality                         Women's Health Nurse Practitioner
# to_organization_name
# HCA HEALTH SERVICES OF TENNESSEE, INC.                               34.0
# HTI MEMORIAL HOSPITAL CORPORATION                                   328.0
# NASHVILLE GENERAL HOSPITAL                                            NaN
# SAINT THOMAS WEST HOSPITAL                                          490.0
# SETON CORPORATION                                                     NaN
# VANDERBILT UNIVERSITY MEDICAL CENTER                               1373.0
#
# [6 rows x 154 columns]

# %%
#AK find the top referred Nashville hospitals by patient count
df_ref.groupby(['to_organization_name', 'from_speciality'])['from_npi'].count().reset_index().sort_values('from_npi', ascending = False)
# Out:
#                        to_organization_name  \
# 323    VANDERBILT UNIVERSITY MEDICAL CENTER
# 298    VANDERBILT UNIVERSITY MEDICAL CENTER
# 199              SAINT THOMAS WEST HOSPITAL
# 15   HCA HEALTH SERVICES OF TENNESSEE, INC.
# 299    VANDERBILT UNIVERSITY MEDICAL CENTER
# ..                                      ...
# 313    VANDERBILT UNIVERSITY MEDICAL CENTER
# 206              SAINT THOMAS WEST HOSPITAL
# 79        HTI MEMORIAL HOSPITAL CORPORATION
# 310    VANDERBILT UNIVERSITY MEDICAL CENTER
# 332    VANDERBILT UNIVERSITY MEDICAL CENTER
#
#                                    from_speciality  from_npi
# 323                    Internal Medicine Physician       319
# 298                      Family Medicine Physician       203
# 199                    Internal Medicine Physician       191
# 15                  Diagnostic Radiology Physician       163
# 299                      Family Nurse Practitioner       146
# ..                                             ...       ...
# 313                            Health Psychologist         1
# 206                       Neuroradiology Physician         1
# 79            Acute Care Clinical Nurse Specialist         1
# 310  Glaucoma Specialist (Ophthalmology) Physician         1
# 332                   Neurology Physical Therapist         1
#
# [400 rows x 3 columns]

# %%
#find top referred hospitals in nashville by patient count
sql = """
WITH cte_nash_hosp AS (
        SELECT distinct npi, organization_name  FROM npi 
        LEFT JOIN taxonomy  USING(taxonomy_code)
        WHERE location_address_state_name = 'TN' 
                AND entity_type_code = 2 
                AND location_address_city_name LIKE 'Nashville%' 
                AND classification = 'General Acute Care Hospital'
)
SELECT n.organization_name as hospital, SUM(patient_count) tot_patients
FROM hop h
        INNER JOIN npi n ON  h.to_npi = n.npi
        INNER JOIN cte_nash_hosp cte ON h.to_npi = cte.npi
GROUP BY n.organization_name
ORDER BY 2 desc
